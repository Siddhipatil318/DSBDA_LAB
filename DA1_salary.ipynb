# %%
# 📌 Step 1: Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
# 📌 Step 3: Define input and output
X = df[['YearsExperience']]  # Independent variable
y = df['Salary']             # Dependent variable

# %%
# 📌 Step 4: Train the Linear Regression model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# 📌 Step 5: Predict salary for 15 years of experience
experience = np.array([[15]])  # reshape to 2D array
predicted_salary = model.predict(experience)[0]
print(f"Predicted Salary for 15 years of experience: ₹{predicted_salary:.2f}")
# Out:
# Predicted Salary for 15 years of experience: ₹167541.64
# C:\Users\Test\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# 📌 Step 6: Plot the regression line
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.scatter(15, predicted_salary, color='green', s=100, marker='x', label='Prediction (15 yrs)')
plt.title("Experience vs Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend()
plt.grid(True)
plt.show()
